# %% [markdown]
# <a href="https://colab.research.google.com/github/Franciscopereztis/Mi-trabajo/blob/main/Clase_del_27_de__junio_Gr%C3%A1ficas_implicitas_param%C3%A9tricas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import symbols, Integral, sin

x=symbols('x')
intsen = Integral(sin(x),(x,-1,1))
print("El resultado es: ", intsen.evalf())
# Out:
# El resultado es:  0.e-100

# %%
from sympy import symbols, integrate, sin, exp, oo

x=symbols('x')

print(integrate(exp(-x),(x,0,oo)))
# Out:
# 1

# %%
from sympy import symbols, integrate, sin, exp, oo
from sympy.plotting import plot

x=symbols('x')

fx=0
for i in range(4):
  fx=fx +sin(i*x)

print(fx)
plot(fx)
# Out:
# sin(x) + sin(2*x) + sin(3*x)

# %%
from sympy import symbols, integrate, sin, exp, oo , Abs
from sympy.plotting import plot

def f(x):
  return Abs(Abs(x)-1)

x=symbols('x')

plot(fx)
plot(f(f(f(x))));
plot(f(x)*f(x), (x,-5,5),line_color="red")

# %% [markdown]
# funciones implicitas

# %%
from sympy import symbols, Eq
from sympy import plot_implicit

x, y = symbols('x y')
eq = Eq(x**2 + y**2, 1)
plot_implicit(Eq(x**4-(x**2-y**3),0), (x,-1.5,1.5),(y,-1.5,1.5));

# %%
from sympy import sqrt, sin
from sympy import plot_implicit


plot_implicit(sin(x**5)+(x-2*y**2)>0, (x,-2,4), (y,-2,2));

# %% [markdown]
# Funciones en forma paramétrica

# %%
from sympy import symbols, sin, cos, exp, pi
from sympy.plotting import plot_parametric
t=symbols('t')
def x(t):
  return sin(t)*(exp(cos(t))-2*cos(4*t)-sin(t/12)**5)

def y(t):
  return cos(t)*(exp(cos(t))-2*cos(4*t)-sin(t/12)**5)

plot_parametric(x(t), y(t), (t,-6*pi, 6*pi));
plot_parametric(x(t), y(t), (t,-50,50));

# %% [markdown]
# coordenadas polares con matplotlin

# %%
import numpy as np
import matplotlib.pyplot as plt

theta =np.linspace(0, 2*np.pi, 4000)
r=3*np.cos(6*theta)
x=r*np.sin(theta)
y=r*np.cos(theta)

plt.plot(x,y);

# %%
import numpy as np
import matplotlib.pyplot as plt

theta =np.linspace(0, 2*np.pi, 4000)
r=3*np.cos(6*theta)
x=r*np.sin(theta)
y=r*np.cos(theta)

plt.axis("off"); #oculatar los ejes
plt.axis("equal")
plt.plot(x,y);

# %% [markdown]
# codigo manera directa

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(1, 4*np.pi, 4000)
r=np.sqrt(3*np.cos(2*theta))

plt.polar(theta, r, marker="+", color=(.2,.4,.5,.3));
plt.title("Lemniscata")
plt.show()
# Out:
# <ipython-input-18-806f62ff4740>:5: RuntimeWarning: invalid value encountered in sqrt
#   r=np.sqrt(3*np.cos(2*theta))
